# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/arsal626/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane 2 — Refresh / Content Opportunity Scoring
#
# I chose this lane because the available starter data contains page-level search, traffic, engagement, freshness, and content signals that can support prioritizing pages for review. The goal is not to predict whether a refresh will definitely succeed, but to identify which pages appear most worth reviewing first based on available evidence.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Question: Which pages should an SEO/content team prioritize for review or potential refresh based on their current search-performance and content signals?
#
# Decision: Decide which pages should be reviewed first.
#
# Action: The team can investigate the highest-priority pages and decide whether to refresh, improve, or leave them unchanged.
#
# Cost of a wrong call: Prioritizing the wrong pages can waste content-team time, while failing to prioritize a genuinely weak page could mean missing an opportunity to improve its search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 30,000 page-level records and 44 columns. The trend_direction field shows that 16,262 pages are marked as down, while 5,962 are stable and 4,388 are up. This suggests there is a substantial group of pages showing a downward trend, making page prioritization a potentially useful decision-support problem. These numbers describe the starter dataset; they do not by themselves show that refreshing a page will improve its performance.

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'flyrank-ml-internship', 'sample_data']

# %%
# !git clone https://github.com/arsal626/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %%
# !ls flyrank-ml-internship
# Out:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
import pandas as pd

df = pd.read_csv(
    "/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv"
)

print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Rows: 30000
# Columns: 44

# %%
print(df["trend_direction"].value_counts())
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# What I can claim: The dataset can help identify and prioritize pages based on observed search-performance and content-related signals. The trend_direction distribution also shows that many pages in the starter data are marked as down.
#
# What I cannot claim: I cannot claim that the analysis will predict Google's ranking algorithm or that refreshing a prioritized page will definitely improve its performance. The analysis is intended to support prioritization and investigation, not guarantee an outcome or prove causation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - ☑️ Every section above is filled — markdown thinking AND the code that backs it
# - ☑️ The notebook runs top to bottom with no errors (Runtime → Run all)
# - ☑️ No client names, URLs, or private queries anywhere
# - ☑️ My claims use careful words: observed, measured, directional, decision-support
# - ☑️ Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
