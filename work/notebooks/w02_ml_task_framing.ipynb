# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/arsal626/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# Lane 2 — Refresh / Content Opportunity Scoring
#
# I frame this lane as a ranking/scoring problem. The goal is to assign pages a priority score so that an SEO or content team can identify which pages are most worth reviewing for a possible refresh. The output is not a guarantee that a refresh will improve a page; it is a way to rank pages for further investigation and action.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# Target/proxy: I would use is_declining_label = trend_direction == "down" as the initial proxy target. It represents whether a page is currently showing a downward trend. This is useful for the starter exercise, but it is only a proxy because it is based on the current observation window rather than a future outcome. For the longer-term project, I would prefer a future-looking target such as whether a page experiences a decline over the next 30 days.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# **Success metric:** Because this is a ranking/scoring problem, I would use Precision@K as the main metric. For example, Precision@50 measures how many of the top 50 pages selected by the model are actually in the target group. This matches the business goal of giving the content team a useful shortlist rather than optimizing overall accuracy across every page. I would also compare the model against a simple fixed-rule baseline to make sure ML provides real improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# !git clone https://github.com/arsal626/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 134 (delta 47), reused 94 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (134/134), 1.85 MiB | 13.05 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
# !ls /content/flyrank-ml-internship/data/raw
# Out:
# content_refresh_anonymized.csv

# %%
print(df.columns.tolist())
# Out:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
page_df = df[[
    "content_id",
    "content_type",
    "content_age_days",
    "impressions_90d",
    "avg_position",
    "ctr",
    "trend_direction"
]].copy()

page_df.head(10)
# Out:
#              content_id     content_type  content_age_days  impressions_90d  \
# 0  content_304f48230142  keyword article               187             3803
# 1  content_a1fb4e703a9e  keyword article               445            15320
# 2  content_9aa793d4d895  keyword article               141            12581
# 3  content_331d6c4de07b  keyword article               463            11751
# 4  content_d99b7a2d90ca  keyword article               263            19140
# 5  content_d4084a4bc775  keyword article               147             3970
# 6  content_9a34b442b552  keyword article                90               20
# 7  content_a63219c6e95a  keyword article               445             1724
# 8  content_5e6c160719bc  keyword article                90            32574
# 9  content_c27558df2b0c  keyword article               257             1240
#
#    avg_position   ctr trend_direction
# 0          10.6  0.76            down
# 1          20.3  0.05            down
# ...

# %%
page_df["is_declining"] = (page_df["trend_direction"] == "down").astype(int)

page_df[[
    "content_id",
    "trend_direction",
    "is_declining"
]].head(10)
# Out:
#              content_id trend_direction  is_declining
# 0  content_304f48230142            down             1
# 1  content_a1fb4e703a9e            down             1
# 2  content_9aa793d4d895            down             1
# 3  content_331d6c4de07b          stable             0
# 4  content_d99b7a2d90ca            down             1
# 5  content_d4084a4bc775            down             1
# 6  content_9a34b442b552            down             1
# 7  content_a63219c6e95a          stable             0
# 8  content_5e6c160719bc            down             1
# 9  content_c27558df2b0c            down             1

# %% [markdown]
# **Target sketch:** is_declining is a binary proxy target where 1 means the page is currently marked as down and 0 means it is not. This gives us a simple starting point for exploring which page-level signals are associated with declining pages. For a future version, a better target would be based on a future observed decline rather than the current trend_direction.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
